# %% [markdown]
# # Day 2 : Data Loading and Manipulation

# %% [markdown]
# ### You can use the following liberaries for your assignment:
# > Numpy, Pandas, Matplotlib, seaborn, LASIO

# %% [markdown]
# ## Kindly load the las file of F02-1_logs.las well from the data folder
# ## Perform the below Tasks:
#
# >1. Plot histogram for every well-log in the las file
# 2. Calculate the 5 points statistics for every well-log (min, Max and Percentiles[0.25,0.5,0.75])
# 3. Using **np.log()** transform the well logs into log of values
# 4. Plot histogram for every well-log after transforming them

# %%
# Importing Libraries
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt

import seaborn as sb
import lasio

# %%
# read las file
F02 = lasio.read("Dutch_F3_Logs\F02-1_logs.las")
# Into dataframe
df = F02.df()
# Curves?
print ('curves: ', F02.keys())
# Out:
# curves:  ['DEPTH', 'RHOB', 'DT', 'GR', 'AI', 'AI_REL', 'PHIE']

# %%
#1. Plot histogram for every well-log in the las file
df.hist(figsize=(15,15));

# %%
#2. Calculate the 5 points statistics for every well-log (min, Max and Percentiles[0.25,0.5,0.75])
df.describe()
# Out:
#               RHOB           DT           GR            AI         AI_REL  \
# count  8253.000000  9680.000000  9666.000000  9.680000e+03    9680.000000
# mean   1975.091074   495.026839    46.613531  4.078518e+06    5193.728898
# std     294.677828    50.861145    23.484662  8.776878e+05  193455.679167
# min    1350.444700   368.114700     1.339200  2.035267e+06 -617319.750000
# 25%    1812.400000   460.693600    23.527000  3.658766e+06  -95113.828100
# 50%    2096.345000   505.393400    48.765250  3.953107e+06    2603.301500
# 75%    2210.906000   521.642300    63.162950  4.782770e+06   93553.453100
# max    2346.629200   667.920800   129.177300  5.983779e+06  629867.000000
#
#               PHIE
# count  4906.000000
# mean      0.304522
# std       0.064282
# min       0.203900
# 25%       0.257900
# 50%       0.283000
# 75%       0.339800
# max       0.709000

# %%
#3. Using np.log() transform the well logs into log of values
log_t=np.log(df)
log_t
# Out:
#                RHOB        DT        GR         AI  AI_REL  PHIE
# DEPTH
# 48.0000         NaN  6.261584       NaN  15.155828     NaN   NaN
# 48.1500         NaN  6.261570       NaN  15.155843     NaN   NaN
# 48.3000         NaN  6.261556       NaN  15.155857     NaN   NaN
# 48.4500         NaN  6.261542       NaN  15.155871     NaN   NaN
# 48.6000         NaN  6.261528       NaN  15.155885     NaN   NaN
# ...             ...       ...       ...        ...     ...   ...
# 1499.2500  7.488598  6.276968  3.318804  15.027157     NaN   NaN
# 1499.4000  7.503383  6.282007  3.350890  15.036863     NaN   NaN
# 1499.5500  7.529218  6.286352  3.352753  15.058374     NaN   NaN
# 1499.7001  7.539239  6.286488  3.352753  15.068261     NaN   NaN
# 1499.8501  7.526359  6.286711  3.331343  15.055160     NaN   NaN
#
# [9680 rows x 6 columns]

# %%
#4. Plot histogram for every well-log after transforming them
log_t.hist(figsize=(15,15));
